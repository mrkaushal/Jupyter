# %% [markdown]
# ##### Tokenization

# %%
import spacy
nlp = spacy.load('en_core_web_lg')

# %%
mystring = '"We\'re moving to L.A.!"'

# %%
print(mystring)
# Out:
# "We're moving to L.A.!"

# %%
doc = nlp(mystring)

# %%
for token in doc:
    print(token.text)
# Out:
# "
# We
# 're
# moving
# to
# L.A.
# !
# "

# %%
doc2 = nlp(u"We're here to help! Send snail-mail, email support@kaushalpatel.info, or text to 855-555-5555, or visit us at http://kaushalpatel.info")

# %%
for token in doc2:
    print(token.text)
# Out:
# We
# 're
# here
# to
# help
# !
# Send
# snail
# -
# mail
# ,
# email
# support@kaushalpatel.info
# ,
# or
# text
# to
# 855
# -
# 555
# -
# 5555
# ,
# or
# visit
# us
# at
# http://kaushalpatel.info

# %%
doc3 = nlp(u"A 5km NYC cab ride cost $10.30")

# %%
for token in doc3:
    print(token.text)
# Out:
# A
# 5
# km
# NYC
# cab
# ride
# cost
# $
# 10.30

# %%
doc4 = nlp(u"Let's visit St. Louis, Missouri! in the United States")

# %%
for token in doc4:
    print(token.text)
# Out:
# Let
# 's
# visit
# St.
# Louis
# ,
# Missouri
# !
# in
# the
# United
# States

# %%
len(doc4)
# Out:
# 12

# %%
doc4.vocab

# %%
len(doc4.vocab)
# Out:
# 819

# %%
doc5 = nlp(u"it is better to be alone than in bad company")

# %%
doc5[0]
# Out:
# it

# %%
doc5[2:8]
# Out:
# better to be alone than in

# %%
doc8 = nlp(u"Apple to build a Hong Kong factory for $1.6bn")

# %%
for token in doc8:
    print(token.text)
# Out:
# Apple
# to
# build
# a
# Hong
# Kong
# factory
# for
# $
# 1.6bn

# %%
for token in doc8:
    print(token.text, end='||')
# Out:
# Apple||to||build||a||Hong||Kong||factory||for||$||1.6bn||

# %%
for entity in doc8.ents:
    print(entity)
    print(entity.label_)
    print(str(spacy.explain(entity.label_)))
    print('\n')
# Out:
# Apple
# ORG
# Companies, agencies, institutions, etc.
#
#
# Hong Kong
# GPE
# Countries, cities, states
#
#
# 1.6bn
# MONEY
# Monetary values, including unit

# %%
doc9 = nlp(u"Autonomous cars shift insurance liability toward manufacturers.")

# %%
for chunk in doc9.noun_chunks:
    print(chunk.text)
# Out:
# Autonomous cars
# insurance liability
# manufacturers

# %%
print(doc9.vocab)

# %%
print(len(doc9.vocab))
# Out:
# 788

# %%
from spacy import displacy

# %%
doc = nlp(u"Apple is going to build a U.K. factory for $6 million")

# %%
displacy.render(doc, style='dep', jupyter=True, options={'distance': 90})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="0acf0d1fe68a4a6a8e438415cabe2564-0" class="displacy" width="1130" height="317.0" direction="ltr" style="max-width: none; height: 317.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Apple</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="140">is</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="140">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
# ...

# %%
doc = nlp(u"Over the last quarter, Apple's stock plummeted to $0.6bn. and sold iPods to $1.5bn")

# %%
displacy.render(doc, style='ent', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Over
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the last quarter
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# ,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Apple
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# 's stock plummeted to $
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     0.6bn
# ...

# %%
doc = nlp(u"This is a sentence. and this is another sentence.")
displacy.serve(doc, style='dep', options={'distance': 100})
# Out:
# e:\Practice\Jupyter\venv\lib\site-packages\spacy\displacy\__init__.py:103: UserWarning: [W011] It looks like you're calling displacy.serve from within a Jupyter notebook or a similar environment. This likely means you're already running a local web server, so there's no need to make displaCy start another one. Instead, you should be able to replace displacy.serve with displacy.render to show the visualization.
#   warnings.warn(Warnings.W011)
# <span class="tex2jax_ignore"><!DOCTYPE html>
# <html lang="en">
#     <head>
#         <title>displaCy</title>
#     </head>
#
#     <body style="font-size: 16px; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Helvetica, Arial, sans-serif, 'Apple Color Emoji', 'Segoe UI Emoji', 'Segoe UI Symbol'; padding: 4rem 2rem; direction: ltr">
# <figure style="margin-bottom: 6rem">
# ...
