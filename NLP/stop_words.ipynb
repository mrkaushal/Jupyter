# %%
import spacy

# %%
nlp = spacy.load("en_core_web_lg")

# %%
print(nlp.Defaults.stop_words)
# Out:
# {'’re', 'himself', 'our', 'top', 'more', 'first', 'had', 'an', 'who', 'at', 'should', 'further', 'therefore', 'until', 'everyone', 'her', 'what', 'other', 'enough', 'whoever', 'but', 'the', 'and', 'three', 'themselves', 'back', 'any', 'see', 'otherwise', 'why', 'nine', 'amount', 'my', 'thereafter', 'those', 'becoming', 'latterly', 'these', 'eight', 'upon', 'made', "'re", 'nobody', 'were', 'sixty', 'ourselves', 'hereby', 'there', 'some', 'something', 'name', 'ten', 'we', 'be', 'somehow', 'two', 'whither', 'really', 'herself', 'because', 'fifteen', "'ll", 'per', 'by', 'twelve', 'toward', 'your', 'during', 'latter', 'herein', 'part', 'of', 'him', 'unless', 'moreover', 'thence', 'down', 'often', 'bottom', 'afterwards', 'take', 'keep', 'next', 'me', 'out', 'though', 'under', 'among', 'every', 'neither', 'nothing', 'using', 'indeed', 'less', 'then', 'nowhere', 'even', 'being', 'such', 'nevertheless', 'has', 'yours', 'least', '’s', 'anywhere', 'amongst', 'throughout', 'regarding', 'only', '
# ...

# %%
len(nlp.Defaults.stop_words)
# Out:
# 326

# %%
nlp.vocab['is']

# %%
nlp.vocab['is'].is_stop
# Out:
# True

# %%
nlp.Defaults.stop_words.add('btw') # add a stop word

# %%
nlp.vocab['btw'].is_stop
# Out:
# True

# %%
len(nlp.Defaults.stop_words)
# Out:
# 327

# %%
nlp.Defaults.stop_words.remove('btw') # remove the word from the stop words

# %%
nlp.vocab['btw'].is_stop = False # remove the word from the stop words

# %%
nlp.vocab['btw'].is_stop
# Out:
# False
